# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | nerchinskiy zavod
# Processing Record 7 of Set 1 | bima
# Processing Record 8 of Set 1 | marawi
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | graaff-reinet
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | kununurra
# Processing Record 17 of Set 1 | margate
# Processing Record 18 of Set 1 | agirish
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | rieti
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | mizdah
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | tervel
# Processing Record 30 of Set 1 | ostersund
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | kinango
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | abaete
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | novikovo
# Processing Record 43 of Set 1 | faya
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | pangnirtung
# Processing Record 46 of Set 1 | codrington
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | tucuman
# Processing Record 49 of Set 1 | mazatlan
# Processing Record 50 of Set 1 | nam dinh
# Processing Record 1 of Set 2 | udachnyy
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | isangel
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | srednekolymsk
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | grand-bourg
# Processing Record 8 of Set 2 | wajima
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | ndele
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | tezu
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | sao sebastiao
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | kamalapuram
# Processing Record 17 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | kiruna
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | terrace
# Processing Record 24 of Set 2 | ginda
# Processing Record 25 of Set 2 | camacha
# Processing Record 26 of Set 2 | sangar
# Processing Record 27 of Set 2 | safaga
# Processing Record 28 of Set 2 | kalofer
# Processing Record 29 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | fenoarivo
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | drymen
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | vila
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | tillabery
# City not found. Skipping...
# Processing Record 40 of Set 2 | montreal
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | alugan
# Processing Record 44 of Set 2 | bud
# Processing Record 45 of Set 2 | sananduva
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | the valley
# Processing Record 48 of Set 2 | maniitsoq
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | grand gaube
# Processing Record 2 of Set 3 | loreto
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | cape town
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | goderich
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | kemijarvi
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | workington
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | itapirapua
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | dundee
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | muli
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | siuna
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | havre-saint-pierre
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | la serena
# Processing Record 28 of Set 3 | kandiaro
# Processing Record 29 of Set 3 | linguere
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | ancud
# Processing Record 34 of Set 3 | west wendover
# Processing Record 35 of Set 3 | quelimane
# Processing Record 36 of Set 3 | khandyga
# Processing Record 37 of Set 3 | praia da vitoria
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | galle
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | hilo
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | dzaoudzi
# Processing Record 46 of Set 3 | pimenta bueno
# Processing Record 47 of Set 3 | trairi
# Processing Record 48 of Set 3 | santa maria
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | egvekinot
# Processing Record 1 of Set 4 | agadez
# Processing Record 2 of Set 4 | marsh harbour
# Processing Record 3 of Set 4 | nuevo progreso
# Processing Record 4 of Set 4 | lilongwe
# Processing Record 5 of Set 4 | menongue
# Processing Record 6 of Set 4 | chester-le-street
# Processing Record 7 of Set 4 | yambio
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | kloulklubed
# Processing Record 10 of Set 4 | pitimbu
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | badou
# Processing Record 13 of Set 4 | westport
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | tiarei
# Processing Record 16 of Set 4 | antalaha
# Processing Record 17 of Set 4 | harlow
# Processing Record 18 of Set 4 | pevek
# Processing Record 19 of Set 4 | krasnoselkup
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | namatanai
# Processing Record 22 of Set 4 | otjimbingwe
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | perevolotskiy
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | lavrentiya
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | tignere
# Processing Record 33 of Set 4 | atikokan
# Processing Record 34 of Set 4 | buzmeyin
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | vila franca do campo
# Processing Record 38 of Set 4 | ye
# City not found. Skipping...
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | yuksekova
# Processing Record 42 of Set 4 | zabid
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | acapulco
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | tanout
# Processing Record 48 of Set 4 | dwarka
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | cairns
# Processing Record 1 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | lac-megantic
# Processing Record 4 of Set 5 | lerwick
# Processing Record 5 of Set 5 | nuuk
# Processing Record 6 of Set 5 | fonte boa
# Processing Record 7 of Set 5 | matara
# Processing Record 8 of Set 5 | hamilton
# Processing Record 9 of Set 5 | bathurst
# Processing Record 10 of Set 5 | gizo
# Processing Record 11 of Set 5 | tete
# Processing Record 12 of Set 5 | russell
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | yerbogachen
# Processing Record 15 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 5 | labuhan
# Processing Record 17 of Set 5 | bac can
# City not found. Skipping...
# Processing Record 18 of Set 5 | pangody
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | obihiro
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | envira
# Processing Record 23 of Set 5 | denpasar
# Processing Record 24 of Set 5 | cooma
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | miguel hidalgo
# Processing Record 28 of Set 5 | nhulunbuy
# Processing Record 29 of Set 5 | bereda
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | mackenzie
# Processing Record 32 of Set 5 | sortland
# Processing Record 33 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | tsaratanana
# Processing Record 36 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | harbour breton
# Processing Record 40 of Set 5 | mumford
# Processing Record 41 of Set 5 | rocha
# Processing Record 42 of Set 5 | semnan
# Processing Record 43 of Set 5 | gryfice
# Processing Record 44 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 5 | kodiak
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | japura
# Processing Record 48 of Set 5 | uchiza
# Processing Record 49 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 5 | cessnock
# Processing Record 1 of Set 6 | waverly
# Processing Record 2 of Set 6 | xinxiang
# Processing Record 3 of Set 6 | vanimo
# Processing Record 4 of Set 6 | morayfield
# Processing Record 5 of Set 6 | coos bay
# Processing Record 6 of Set 6 | benguela
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | emerald
# Processing Record 9 of Set 6 | tocopilla
# Processing Record 10 of Set 6 | lithgow
# Processing Record 11 of Set 6 | concarneau
# Processing Record 12 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 6 | karlskoga
# Processing Record 14 of Set 6 | starosubkhangulovo
# Processing Record 15 of Set 6 | yulara
# Processing Record 16 of Set 6 | san cristobal
# Processing Record 17 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 6 | tual
# Processing Record 19 of Set 6 | lakes entrance
# Processing Record 20 of Set 6 | aranos
# Processing Record 21 of Set 6 | el badari
# City not found. Skipping...
# Processing Record 22 of Set 6 | dakar
# Processing Record 23 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | iquitos
# Processing Record 26 of Set 6 | lindi
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | tasiilaq
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | sorong
# Processing Record 31 of Set 6 | aklavik
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | kysyl-syr
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | varhaug
# Processing Record 36 of Set 6 | romny
# Processing Record 37 of Set 6 | corpus christi
# Processing Record 38 of Set 6 | brownwood
# Processing Record 39 of Set 6 | kaffrine
# Processing Record 40 of Set 6 | sioux lookout
# Processing Record 41 of Set 6 | baryshivka
# Processing Record 42 of Set 6 | uk
# City not found. Skipping...
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | santa rosa
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | havoysund
# Processing Record 47 of Set 6 | katherine
# Processing Record 48 of Set 6 | bajil
# Processing Record 49 of Set 6 | miraflores
# Processing Record 50 of Set 6 | husavik
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | alvaraes
# Processing Record 3 of Set 7 | horodkivka
# Processing Record 4 of Set 7 | hualmay
# Processing Record 5 of Set 7 | iracoubo
# Processing Record 6 of Set 7 | seoul
# Processing Record 7 of Set 7 | chingirlau
# Processing Record 8 of Set 7 | borogontsy
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | sulangan
# Processing Record 11 of Set 7 | terme
# Processing Record 12 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 7 | mareeba
# Processing Record 14 of Set 7 | atar
# Processing Record 15 of Set 7 | abadiania
# Processing Record 16 of Set 7 | oro valley
# Processing Record 17 of Set 7 | longjiang
# Processing Record 18 of Set 7 | nassau
# Processing Record 19 of Set 7 | xiamen
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | arinos
# Processing Record 22 of Set 7 | mao
# Processing Record 23 of Set 7 | grindavik
# Processing Record 24 of Set 7 | pacific grove
# Processing Record 25 of Set 7 | upernavik
# Processing Record 26 of Set 7 | kilimatinde
# Processing Record 27 of Set 7 | bilma
# Processing Record 28 of Set 7 | itaqui
# Processing Record 29 of Set 7 | acarau
# Processing Record 30 of Set 7 | lambarene
# Processing Record 31 of Set 7 | riyadh
# Processing Record 32 of Set 7 | port hardy
# Processing Record 33 of Set 7 | illapel
# Processing Record 34 of Set 7 | cap malheureux
# Processing Record 35 of Set 7 | nantucket
# Processing Record 36 of Set 7 | la rioja
# Processing Record 37 of Set 7 | telma
# Processing Record 38 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 7 | lisakovsk
# Processing Record 40 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 7 | jiexiu
# Processing Record 42 of Set 7 | willowmore
# Processing Record 43 of Set 7 | qaqortoq
# Processing Record 44 of Set 7 | filingue
# Processing Record 45 of Set 7 | dawei
# Processing Record 46 of Set 7 | norman wells
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | markova
# Processing Record 49 of Set 7 | gat
# Processing Record 50 of Set 7 | zhigansk
# Processing Record 1 of Set 8 | port hedland
# Processing Record 2 of Set 8 | ornskoldsvik
# Processing Record 3 of Set 8 | rawson
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | sechura
# Processing Record 7 of Set 8 | borova
# Processing Record 8 of Set 8 | sabha
# Processing Record 9 of Set 8 | vostok
# Processing Record 10 of Set 8 | iqaluit
# Processing Record 11 of Set 8 | cidreira
# Processing Record 12 of Set 8 | veraval
# Processing Record 13 of Set 8 | burica
# City not found. Skipping...
# Processing Record 14 of Set 8 | souris
# Processing Record 15 of Set 8 | lukovetskiy
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | razole
# Processing Record 18 of Set 8 | caravelas
# Processing Record 19 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 8 | verkhnechusovskiye gorodki
# Processing Record 21 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 8 | saint-paul
# Processing Record 23 of Set 8 | whitehorse
# Processing Record 24 of Set 8 | harare
# Processing Record 25 of Set 8 | dhidhdhoo
# Processing Record 26 of Set 8 | havelock
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | leh
# Processing Record 29 of Set 8 | zaton
# Processing Record 30 of Set 8 | burnie
# Processing Record 31 of Set 8 | aden
# Processing Record 32 of Set 8 | manuk mangkaw
# Processing Record 33 of Set 8 | penzance
# Processing Record 34 of Set 8 | porto santo
# Processing Record 35 of Set 8 | rio grande
# Processing Record 36 of Set 8 | izumo
# Processing Record 37 of Set 8 | uddevalla
# Processing Record 38 of Set 8 | centralia
# Processing Record 39 of Set 8 | miles city
# Processing Record 40 of Set 8 | teresita
# Processing Record 41 of Set 8 | corning
# Processing Record 42 of Set 8 | slavuta
# Processing Record 43 of Set 8 | sao felix do xingu
# Processing Record 44 of Set 8 | zhuhai
# Processing Record 45 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 8 | locri
# Processing Record 47 of Set 8 | bairiki
# Processing Record 48 of Set 8 | baghdad
# Processing Record 49 of Set 8 | quatre cocos
# Processing Record 50 of Set 8 | ust-tsilma
# Processing Record 1 of Set 9 | finschhafen
# Processing Record 2 of Set 9 | sao gabriel da cachoeira
# Processing Record 3 of Set 9 | camacari
# Processing Record 4 of Set 9 | chuy
# Processing Record 5 of Set 9 | norrtalje
# Processing Record 6 of Set 9 | chicama
# Processing Record 7 of Set 9 | suntar
# City not found. Skipping...
# Processing Record 8 of Set 9 | paamiut
# Processing Record 9 of Set 9 | kawalu
# Processing Record 10 of Set 9 | pisco
# Processing Record 11 of Set 9 | capitan bado
# Processing Record 12 of Set 9 | rio gallegos
# Processing Record 13 of Set 9 | omsukchan
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | samarai
# Processing Record 16 of Set 9 | ambon
# Processing Record 17 of Set 9 | sola
# Processing Record 18 of Set 9 | ostrovnoy
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | mikhaylovka
# Processing Record 21 of Set 9 | snasa
# Processing Record 22 of Set 9 | nanpiao
# Processing Record 23 of Set 9 | saint-joseph
# Processing Record 24 of Set 9 | sale
# Processing Record 25 of Set 9 | takhtamygda
# Processing Record 26 of Set 9 | kampot
# Processing Record 27 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 9 | sarangani
# Processing Record 29 of Set 9 | vao
# Processing Record 30 of Set 9 | vidim
# Processing Record 31 of Set 9 | guerrero negro
# Processing Record 32 of Set 9 | ahipara
# Processing Record 33 of Set 9 | pavino
# Processing Record 34 of Set 9 | port-gentil
# Processing Record 35 of Set 9 | nombre de dios
# Processing Record 36 of Set 9 | sinnamary
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | sao jose do belmonte
# Processing Record 39 of Set 9 | brigantine
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | esmeraldas
# Processing Record 42 of Set 9 | alamogordo
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | formosa
# Processing Record 45 of Set 9 | byron bay
# Processing Record 46 of Set 9 | nueva helvecia
# Processing Record 47 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 48 of Set 9 | sompeta
# Processing Record 49 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 10 | shetpe
# Processing Record 2 of Set 10 | riverton
# Processing Record 3 of Set 10 | slave lake
# Processing Record 4 of Set 10 | shinpokh
# Processing Record 5 of Set 10 | saint-pierre
# Processing Record 6 of Set 10 | cahors
# Processing Record 7 of Set 10 | chara
# Processing Record 8 of Set 10 | batagay-alyta
# Processing Record 9 of Set 10 | yeppoon
# Processing Record 10 of Set 10 | tugdan
# Processing Record 11 of Set 10 | karimganj
# Processing Record 12 of Set 10 | mezen
# Processing Record 13 of Set 10 | takayama
# Processing Record 14 of Set 10 | arlit
# Processing Record 15 of Set 10 | torres
# Processing Record 16 of Set 10 | camabatela
# Processing Record 17 of Set 10 | bacolod
# Processing Record 18 of Set 10 | buin
# Processing Record 19 of Set 10 | calama
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | sambava
# Processing Record 22 of Set 10 | oussouye
# Processing Record 23 of Set 10 | birin
# Processing Record 24 of Set 10 | luganville
# Processing Record 25 of Set 10 | manthani
# Processing Record 26 of Set 10 | korla
# Processing Record 27 of Set 10 | covington
# Processing Record 28 of Set 10 | dalbeattie
# Processing Record 29 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | taldan
# Processing Record 32 of Set 10 | freeport
# Processing Record 33 of Set 10 | verkhovazhye
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | sesheke
# Processing Record 36 of Set 10 | bara
# Processing Record 37 of Set 10 | cabedelo
# Processing Record 38 of Set 10 | san quintin
# Processing Record 39 of Set 10 | bandarbeyla
# Processing Record 40 of Set 10 | khani
# Processing Record 41 of Set 10 | hokitika
# Processing Record 42 of Set 10 | morondava
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | misratah
# Processing Record 45 of Set 10 | ivanava
# Processing Record 46 of Set 10 | porto nacional
# Processing Record 47 of Set 10 | kroderen
# City not found. Skipping...
# Processing Record 48 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 10 | taltal
# Processing Record 50 of Set 10 | qianan
# Processing Record 1 of Set 11 | puerto escondido
# Processing Record 2 of Set 11 | urucara
# Processing Record 3 of Set 11 | sillamae
# Processing Record 4 of Set 11 | udomlya
# Processing Record 5 of Set 11 | comodoro rivadavia
# Processing Record 6 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | alekseyevka
# Processing Record 9 of Set 11 | novaya ladoga
# Processing Record 10 of Set 11 | najran
# Processing Record 11 of Set 11 | daru
# Processing Record 12 of Set 11 | rantepao
# Processing Record 13 of Set 11 | promyshlennaya
# Processing Record 14 of Set 11 | coxim
# Processing Record 15 of Set 11 | tupiza
# Processing Record 16 of Set 11 | seymchan
# Processing Record 17 of Set 11 | atherton
# Processing Record 18 of Set 11 | mnogovershinnyy
# Processing Record 19 of Set 11 | hobyo
# Processing Record 20 of Set 11 | felipe carrillo puerto
# Processing Record 21 of Set 11 | kundiawa
# Processing Record 22 of Set 11 | evensk
# Processing Record 23 of Set 11 | ouro fino
# Processing Record 24 of Set 11 | campoverde
# Processing Record 25 of Set 11 | talaya
# Processing Record 26 of Set 11 | dingle
# Processing Record 27 of Set 11 | muravlenko
# Processing Record 28 of Set 11 | komsomolskiy
# Processing Record 29 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 11 | erzin
# Processing Record 31 of Set 11 | wagar
# Processing Record 32 of Set 11 | wilmington
# Processing Record 33 of Set 11 | xining
# Processing Record 34 of Set 11 | xingyi
# Processing Record 35 of Set 11 | bagli
# Processing Record 36 of Set 11 | urusha
# Processing Record 37 of Set 11 | avera
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | khasan
# Processing Record 40 of Set 11 | nara
# Processing Record 41 of Set 11 | tabory
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | aykhal
# Processing Record 44 of Set 11 | superior
# Processing Record 45 of Set 11 | breves
# Processing Record 46 of Set 11 | nizwa
# Processing Record 47 of Set 11 | ochakiv
# Processing Record 48 of Set 11 | chengde
# Processing Record 49 of Set 11 | arivonimamo
# Processing Record 50 of Set 11 | orlik
# Processing Record 1 of Set 12 | saquena
# Processing Record 2 of Set 12 | sinjai
# Processing Record 3 of Set 12 | kralendijk
# Processing Record 4 of Set 12 | raduzhnyy
# Processing Record 5 of Set 12 | murray bridge
# Processing Record 6 of Set 12 | palmer
# Processing Record 7 of Set 12 | marienburg
# Processing Record 8 of Set 12 | sal rei
# Processing Record 9 of Set 12 | jasper
# Processing Record 10 of Set 12 | gerede
# Processing Record 11 of Set 12 | bahia blanca
# Processing Record 12 of Set 12 | boyolangu
# Processing Record 13 of Set 12 | ryuo
# Processing Record 14 of Set 12 | dunedin
# Processing Record 15 of Set 12 | mount darwin
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | sur
# Processing Record 18 of Set 12 | campos belos
# Processing Record 19 of Set 12 | oyem
# Processing Record 20 of Set 12 | ponta delgada
# Processing Record 21 of Set 12 | ust-kalmanka
# Processing Record 22 of Set 12 | bocas del toro
# Processing Record 23 of Set 12 | lang suan
# Processing Record 24 of Set 12 | yanam
# Processing Record 25 of Set 12 | mangai
# Processing Record 26 of Set 12 | parana
# Processing Record 27 of Set 12 | sosua
# Processing Record 28 of Set 12 | kazachinskoye
# Processing Record 29 of Set 12 | ust-charyshskaya pristan
# Processing Record 30 of Set 12 | oriximina
# Processing Record 31 of Set 12 | kualakapuas
# Processing Record 32 of Set 12 | kot samaba
# Processing Record 33 of Set 12 | puerto leguizamo
# Processing Record 34 of Set 12 | pedernales
# Processing Record 35 of Set 12 | calbuco
# Processing Record 36 of Set 12 | ca mau
# Processing Record 37 of Set 12 | baykit
# Processing Record 38 of Set 12 | klyuchi
# Processing Record 39 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 12 | khlevnoye
# Processing Record 41 of Set 12 | fuerte olimpo
# Processing Record 42 of Set 12 | codo
# Processing Record 43 of Set 12 | san jeronimo
# Processing Record 44 of Set 12 | flinders
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | okhotsk
# Processing Record 47 of Set 12 | koutsouras
# Processing Record 48 of Set 12 | hirara
# Processing Record 49 of Set 12 | mandalgovi
# Processing Record 50 of Set 12 | saint george
# Processing Record 1 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 13 | kjollefjord
# Processing Record 3 of Set 13 | wanning
# Processing Record 4 of Set 13 | macusani
# Processing Record 5 of Set 13 | nouakchott
# Processing Record 6 of Set 13 | ginir
# Processing Record 7 of Set 13 | bitung
# Processing Record 8 of Set 13 | saint-augustin
# Processing Record 9 of Set 13 | ullal
# Processing Record 10 of Set 13 | mayo
# Processing Record 11 of Set 13 | burley
# Processing Record 12 of Set 13 | asau
# Processing Record 13 of Set 13 | tulun
# Processing Record 14 of Set 13 | bonavista
# Processing Record 15 of Set 13 | tiznit
# Processing Record 16 of Set 13 | todos santos
# Processing Record 17 of Set 13 | ridgecrest
# Processing Record 18 of Set 13 | shebekino
# Processing Record 19 of Set 13 | biltine
# Processing Record 20 of Set 13 | zhetysay
# Processing Record 21 of Set 13 | barcelos
# Processing Record 22 of Set 13 | shelburne
# Processing Record 23 of Set 13 | yekimovichi
# Processing Record 24 of Set 13 | brae
# Processing Record 25 of Set 13 | svetlogorsk
# Processing Record 26 of Set 13 | zhuanghe
# Processing Record 27 of Set 13 | iskateley
# Processing Record 28 of Set 13 | waynesville
# Processing Record 29 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 13 | soe
# Processing Record 31 of Set 13 | puquio
# Processing Record 32 of Set 13 | malanje
# Processing Record 33 of Set 13 | high prairie
# Processing Record 34 of Set 13 | cantagallo
# Processing Record 35 of Set 13 | iquique
# Processing Record 36 of Set 13 | narsaq
# Processing Record 37 of Set 13 | chincha alta
# Processing Record 38 of Set 13 | awash
# Processing Record 39 of Set 13 | saint-ambroise
# Processing Record 40 of Set 13 | turbat
# Processing Record 41 of Set 13 | shubarshi
# Processing Record 42 of Set 13 | quthing
# Processing Record 43 of Set 13 | dunkwa
# Processing Record 44 of Set 13 | fatezh
# Processing Record 45 of Set 13 | ciudad bolivar
# Processing Record 46 of Set 13 | akcakoca
# Processing Record 47 of Set 13 | kirakira
# Processing Record 48 of Set 13 | bantry
# Processing Record 49 of Set 13 | ebolowa
# Processing Record 50 of Set 13 | pinega
# Processing Record 1 of Set 14 | buchanan
# Processing Record 2 of Set 14 | ewa beach
# Processing Record 3 of Set 14 | alcaniz
# Processing Record 4 of Set 14 | zyryanskoye
# Processing Record 5 of Set 14 | poronaysk
# Processing Record 6 of Set 14 | ndola
# Processing Record 7 of Set 14 | portland
# Processing Record 8 of Set 14 | sao borja
# Processing Record 9 of Set 14 | bodden town
# Processing Record 10 of Set 14 | beryslav
# Processing Record 11 of Set 14 | harper
# Processing Record 12 of Set 14 | touros
# Processing Record 13 of Set 14 | honningsvag
# Processing Record 14 of Set 14 | zaozerne
# Processing Record 15 of Set 14 | champerico
# Processing Record 16 of Set 14 | lodwar
# Processing Record 17 of Set 14 | svetlyy
# Processing Record 18 of Set 14 | coracora
# Processing Record 19 of Set 14 | conde
# Processing Record 20 of Set 14 | paracuru
# Processing Record 21 of Set 14 | millinocket
# Processing Record 22 of Set 14 | primorsk
# Processing Record 23 of Set 14 | gourdon
# Processing Record 24 of Set 14 | campbell river
# Processing Record 25 of Set 14 | sosnovo-ozerskoye
# Processing Record 26 of Set 14 | chilca
# Processing Record 27 of Set 14 | isiro
# Processing Record 28 of Set 14 | ketchikan
# Processing Record 29 of Set 14 | ribas do rio pardo
# Processing Record 30 of Set 14 | sterling
# Processing Record 31 of Set 14 | north charleston
# Processing Record 32 of Set 14 | tsagan aman
# Processing Record 33 of Set 14 | novobirilyussy
# Processing Record 34 of Set 14 | batagay
# Processing Record 35 of Set 14 | vestmannaeyjar
# Processing Record 36 of Set 14 | uaua
# Processing Record 37 of Set 14 | vung tau
# Processing Record 38 of Set 14 | san patricio
# Processing Record 39 of Set 14 | yeniseysk
# Processing Record 40 of Set 14 | imabari
# City not found. Skipping...
# Processing Record 41 of Set 14 | gazojak
# Processing Record 42 of Set 14 | cestas
# Processing Record 43 of Set 14 | dostpur
# Processing Record 44 of Set 14 | morbegno
# Processing Record 45 of Set 14 | port moresby
# Processing Record 46 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 47 of Set 14 | poyarkovo
# Processing Record 48 of Set 14 | san luis
# Processing Record 49 of Set 14 | salobrena
# Processing Record 50 of Set 14 | florianopolis
# Processing Record 1 of Set 15 | mitsamiouli
# Processing Record 2 of Set 15 | huangmei
# Processing Record 3 of Set 15 | emba
# Processing Record 4 of Set 15 | outjo
# Processing Record 5 of Set 15 | salamanca
# Processing Record 6 of Set 15 | williston
# Processing Record 7 of Set 15 | upata
# Processing Record 8 of Set 15 | mahibadhoo
# Processing Record 9 of Set 15 | kozhva
# Processing Record 10 of Set 15 | vinh
# Processing Record 11 of Set 15 | kautokeino
# Processing Record 12 of Set 15 | alice springs
# Processing Record 13 of Set 15 | raudeberg
# Processing Record 14 of Set 15 | rodrigues alves
# Processing Record 15 of Set 15 | kumluca
# Processing Record 16 of Set 15 | iwakuni
# Processing Record 17 of Set 15 | lichuan
# Processing Record 18 of Set 15 | sovetskiy
# Processing Record 19 of Set 15 | anadyr
# Processing Record 20 of Set 15 | hervey bay
# Processing Record 21 of Set 15 | bambanglipuro
# Processing Record 22 of Set 15 | arkhangelsk
# Processing Record 23 of Set 15 | kattivakkam
# Processing Record 24 of Set 15 | haines junction
# Processing Record 25 of Set 15 | ankazobe
# Processing Record 26 of Set 15 | amazar
# Processing Record 27 of Set 15 | jishou
# Processing Record 28 of Set 15 | yar-sale
# Processing Record 29 of Set 15 | wazzan
# City not found. Skipping...
# Processing Record 30 of Set 15 | abong mbang
# Processing Record 31 of Set 15 | panguna
# Processing Record 32 of Set 15 | san juan
# Processing Record 33 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 15 | hay river
# Processing Record 35 of Set 15 | matagami
# Processing Record 36 of Set 15 | katobu
# Processing Record 37 of Set 15 | multan
# Processing Record 38 of Set 15 | les escoumins
# Processing Record 39 of Set 15 | sainte-anne-des-monts
# Processing Record 40 of Set 15 | narbonne
# Processing Record 41 of Set 15 | ulladulla
# Processing Record 42 of Set 15 | lahat
# Processing Record 43 of Set 15 | lethem
# Processing Record 44 of Set 15 | myitkyina
# Processing Record 45 of Set 15 | bardiyah
# Processing Record 46 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 15 | bida
# Processing Record 48 of Set 15 | palizada
# Processing Record 49 of Set 15 | laguna
# Processing Record 50 of Set 15 | houston
# Processing Record 1 of Set 16 | stornoway
# Processing Record 2 of Set 16 | zyryanka
# Processing Record 3 of Set 16 | wollongong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Talnakh  69.4865   88.3972     -8.59        99          89
# 1     Port Elizabeth -33.9180   25.5701     63.32        82          79
# 2     Cabo San Lucas  22.8909 -109.9124     67.51        80          25
# 3            Qaanaaq  77.4840  -69.3632     -0.36        64          95
# 4  Nerchinskiy Zavod  51.3088  119.6100     -7.20        94          76
# 5               Bima  -8.4667  118.7167     85.91        76          97
# 6             Marawi   7.9986  124.2928     71.78        89         100
# 7          Busselton -33.6500  115.3333     83.01        34          75
# 8            Rikitea -23.1203 -134.9692     79.47        67          19
# 9            Ushuaia -54.8000  -68.3000     46.22        85          51
#
#    Wind Speed Country Current Description
# 0        4.32      RU     overcast clouds
# 1        1.99      ZA       broken clouds
# 2        5.55      MX    scattered clouds
# 3        6.87      GL     overcast clouds
# 4        3.15      RU       broken clouds
# 5        3.09      ID     overcast clouds
# 6        3.91      PH       moderate rain
# 7        0.98      AU       broken clouds
# 8       11.21      PF          few clouds
# 9        7.34      AR       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description',]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Talnakh      RU  69.4865   88.3972     -8.59        99
# 1     Port Elizabeth      ZA -33.9180   25.5701     63.32        82
# 2     Cabo San Lucas      MX  22.8909 -109.9124     67.51        80
# 3            Qaanaaq      GL  77.4840  -69.3632     -0.36        64
# 4  Nerchinskiy Zavod      RU  51.3088  119.6100     -7.20        94
# 5               Bima      ID  -8.4667  118.7167     85.91        76
# 6             Marawi      PH   7.9986  124.2928     71.78        89
# 7          Busselton      AU -33.6500  115.3333     83.01        34
# 8            Rikitea      PF -23.1203 -134.9692     79.47        67
# 9            Ushuaia      AR -54.8000  -68.3000     46.22        85
#
#    Cloudiness  Wind Speed Current Description
# 0          89        4.32     overcast clouds
# 1          79        1.99       broken clouds
# 2          25        5.55    scattered clouds
# 3          95        6.87     overcast clouds
# 4          76        3.15       broken clouds
# 5          97        3.09     overcast clouds
# 6         100        3.91       moderate rain
# 7          75        0.98       broken clouds
# 8          19       11.21          few clouds
# 9          51        7.34       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
